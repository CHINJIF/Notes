# %% [markdown]
# ## Knowledge tree
#
# ### I. 计算机网络
# * 负载均衡
#     * DNS负载均衡
#     * 算法
#         * 无状态链接
#         * 有状态链接 - 一致性哈希
#     * 策略
#         * 简单轮询
#         * 最闲轮询
#         * 加权轮询
# * 过载
#     * 过载恢复策略
# * 协议
#     * TCP
#         * 三次握手，四次挥手
#     * HTTP
#     * AMQP
#     * SOAP
# * 网络编程
#   * python 基于soket编程
#   * python Blocking call/None Blocking/异步编程
#   * JAVA NIO原理 + Netty
# * 编码与序列化
#     * 数据压缩比，支持的数据类型, 常见序列化产品横向对比
#     * avro
#     * xml/json
#     * parquet
#
# ### II. 分布式系统一致性，可用性解决方案
# * 数据一致性，选举算法 处理数据冲突
#     * paxos算法
#     * Raft
#         * Raft的算法实现
# * 服务可用性
#     * master/slave
#     * active/standby
#     * leader/follower
#
# ### III. 分布式系统架构
# * 架构框架
#     * 垂直架构
#     * RPC
#         * 基于RabbitMQ的实现
#     * SOA
#         * Bloomberg BAS
#         * zookeeper + dubbo
#     * 微服务
#         * Docker and Container
#         * Kubernetes核心原理
#
# ### IV. 分布式技术细节
# * 消息队列
#     * RabbitMQ
#     * Kafka
#     * 模式：push/pull, Hello，Work Queue，Publish/Subscribe，Routing，Topics，RPC Request/reply
# * 分布式锁
#     * 基于Chubby实现
#     * 基于Zookeeper实现
#     * 基于redis实现
# * 缓存
#     * 构建LRU Cache
#     * 构建LFU Cache
#
# ### V. 存储
# * 数据存储
#     * S3/ceph
#     * HDFS
# * ACID & BASE & CAP 原理
# * NOSQL，简单原理了解，数据建模区别，应用场景
#     * Memchache、Redis
#     * HBASE
#     * Mongodb
# * 数据索引
#     * b+ tree插入/删除/查找
#     * solr/es简单原理
#     * solr数据结构
#     * inverted index算法
#     * 应用细节，分词，stopword
#     * solr query会写
#
# ### VI. 其他
# * 系统监控
#     * splunk
#     * grafana
# * 测试
# * 数据结构
#     * priority queue 堆
#     * python deque
#
# #### 盲点
# * Thunder Herd
# * pull mode, push mode
# * AMAZON SQS
# * CDN
